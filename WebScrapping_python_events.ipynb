# %% [markdown]
# <a href="https://colab.research.google.com/github/MukherjeeSangita/ml_project/blob/master/WebScrapping_python_events.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Web Scrapping using Beautifulsoup

# %%
import requests 
import pandas as pd
from bs4 import BeautifulSoup
from collections import defaultdict

url='https://www.python.org/events/python-events'
res=requests.get(url)
soup=BeautifulSoup(res.text, 'html.parser')
events= soup.find('ul',{'class':'list-recent-events'}).findAll('li')
details= defaultdict(list)
for event in events:
    title=event.h3.text
    location=event.find('span',{'class':'event-location'}).text
    time=event.find("time").text
    details['title'].append(title)
    details['location'].append(location)
    details['time']=time
pd.DataFrame(details)
# Out:
#                    title                        location  \
# 0        PyCon APAC 2022                  Online, Taiwan
# 1          PyCon SK 2022            Bratislava, Slovakia
# 2             PyBay 2022  San Francsisco, USA and Online
# 3             PyHEP 2022                          Online
# 4          PyCon UK 2022           Cardiff City Hall, UK
# 5  DjangoCon Europe 2022                 Porto, Portugal
#
#                         time
# 0  21 Sept. – 25 Sept.  2022
# 1  21 Sept. – 25 Sept.  2022
# 2  21 Sept. – 25 Sept.  2022
# 3  21 Sept. – 25 Sept.  2022
# 4  21 Sept. – 25 Sept.  2022
# 5  21 Sept. – 25 Sept.  2022
